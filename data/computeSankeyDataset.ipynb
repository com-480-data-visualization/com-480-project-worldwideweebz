# %%
import pandas as pd
from pprint import pprint

csv = pd.read_csv("anime_cleaned.csv", usecols = ["studio", "anime_id", "score", "genre"])
studios = set(csv["studio"])
genres = {'Comedy','Action','Fantasy','Adventure','Drama'}
score = {9.0, 8.0,7.0, 6.0, 5.0, 4.0, 3.0, 2.0, 1.0, 0.0}

# %%
studio_dic = dict()
for s in studios:
    
    studio_dic[s] = dict()
    studio_dic[s]["length"] = len(csv[csv["studio"].str.contains(s)])
    for genre in genres:
        studio_dic[s][genre] = list(csv[csv["genre"].str.contains(genre, na=False)][csv["studio"].str.contains(s)]["anime_id"])
# Out:
# C:\Users\Joachim\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
def meanScorePerGenre(animes):
    scores = dict()
    for s in score:
        scores[s] = 0
    for anime in animes:
        mean = round(csv.loc[csv["anime_id"] == anime]["score"])
        if int(mean) in score:
            scores[int(mean)] += 1
    return scores

# %%
def initGenreDico():
    dico = dict()
    for g in genres:
        dico[g] = 0
    return dico

def initNotesDico():
    dico = dict()
    for n in score:
        dico[n] = 0
    return dico

# %%
def sortAlphab(x, y, xTo="", yTo=""):
    if x <= y and xTo <= yTo: return -1
    return 1
    
def checkIfSameComponent(x, y):
    if(("studioPr" in x and "studioPr" in y) or
      ("genre" in x and "genre" in y) or
      ("info" in x and "info" in y)): 
        return sortAlphab(x["from"], y["from"])
    if(("to" in x and "-0" in x["id"] and "to" in y and "-0" in y["id"]) or
      ("to" in x and "-1" in x["id"] and "to" in y and "-1" in y["id"])):
        return sortAlphab(x["from"], y["from"], x["to"], y["to"])
    return 10

def sankeyDatasort(x, y):
    sameComp = checkIfSameComponent(x, y) 
    if ("studioPr" in x): return -1 if (sameComp == 10) else sameComp
    elif ("genre" in x and not("studioPr" in y)): return -1 if (sameComp == 10) else sameComp
    elif ("note" in x and (not("studioPr" in y or "genre" in y))): return -1 if (sameComp == 10) else sameComp
    elif ("to" in x and "-0" in x["id"] and (not("studioPr" in y or "genre" in y or "note" in y))): return -1 if (sameComp == 10) else sameComp
    else: return 1

# %%
from functools import cmp_to_key

dataAll = []

topStudios = sorted(studio_dic.items(), reverse=True, key=lambda x: x[1]["length"])[:10]

countGenre = initGenreDico()
countNotes = initNotesDico()
                    
for studio, rest in topStudios:
    dataAll.append({"from" : studio, "value": 0, "id":"none", "info": "Number of animes producted : "+str(studio_dic[studio]["length"]), "studioPr": ""})
    for genre, animes in rest.items():
        if(genre != "length"):
            currId = ''.join(filter(str.isalpha, studio))[:2].join(filter(str.isalpha, studio))[-3:]+genre[:2]
            countGenre[genre] += len(animes)
            if(len(animes) != 0):
                dataAll.append({"from": studio, "to": genre, "value": len(animes), "id": currId+"-0" })
            scores = meanScorePerGenre(animes)
            for note, mean in scores.items():
                countNotes[note] += mean
                if(mean != 0):
                    dataAll.append({"from": genre, "to": str(note), "value": mean, "id": currId+"-1" })
                    
for g, count in countGenre.items():
    dataAll.append({"from" : g, "value": 0, "id":"none", "info": "Number of animes : "+str(count), "genre": ""})
for n, count in countNotes.items():
    dataAll.append({"from" : str(n), "value": 0, "id":"none", "info": "Number of animes : "+str(count), "note": ""})
dataAll.append({"from": "Fantasy", "to": '0.0', "value": 1, "id": "none"})
dataAll.append({"from": "Fantasy", "to": '1.0', "value": 1, "id": "none"})
dataAll = sorted(dataAll, key=cmp_to_key(sankeyDatasort))

# %%
import json

with open('C:/Users/Joachim/Documents/Git/repository/com-480-project-worldwideweebz/app/public/data/sankey_dataset.json', 'w') as outfile:
    json.dump(dataAll, outfile)

# %%
pprint(dataAll)
# Out:
# [{'from': 'A-1 Pictures',
#   'id': 'none',
#   'info': 'Number of animes producted : 174',
#   'studioPr': ''},
#  {'from': 'AIC',
#   'id': 'none',
#   'info': 'Number of animes producted : 161',
#   'studioPr': ''},
#  {'from': 'J.C.Staff',
#   'id': 'none',
#   'info': 'Number of animes producted : 251',
#   'studioPr': ''},
#  {'from': 'Madhouse',
#   'id': 'none',
#   'info': 'Number of animes producted : 277',
#   'studioPr': ''},
#  {'from': 'Production I.G',
#   'id': 'none',
#   'info': 'Number of animes producted : 222',
#   'studioPr': ''},
#  {'from': 'Studio Deen',
#   'id': 'none',
#   'info': 'Number of animes producted : 223',
#   'studioPr': ''},
#  {'from': 'Studio Pierrot',
#   'id': 'none',
#   'info': 'Number of animes producted : 248',
#   'studioPr': ''},
#  {'from': 'Sunrise',
#   'id': 'none',
#   'info': 'Number of animes producted : 291',
#   'studioPr': ''},
#  {'from': 'TMS Entertainment',
#   'id': 'none',
#   'info': 'Number of animes producted : 172',
#   'studioPr': ''},
#  {'from': 'Toei Animation',
#   'id': 'none',
#   'info': 'Number of animes producted : 419',
#   'studioPr': ''},
#  {'from': 'Action',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 912'},
#  {'from': 'Adventure',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 632'},
#  {'from': 'Comedy',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 1173'},
#  {'from': 'Drama', 'genre': '', 'id': 'none', 'info': 'Number of animes : 614'},
#  {'from': 'Fantasy',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 592'},
#  {'from': 'Romance',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 465'},
#  {'from': 'Sci-Fi',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 631'},
#  {'from': 'Shounen',
#   'genre': '',
#   'id': 'none',
#   'info': 'Number of animes : 693'},
#  {'from': '0.0', 'id': 'none', 'info': 'Number of animes : 0', 'note': ''},
#  {'from': '1.0', 'id': 'none', 'info': 'Number of animes : 0', 'note': ''},
#  {'from': '2.0', 'id': 'none', 'info': 'Number of animes : 2', 'note': ''},
#  {'from': '3.0', 'id': 'none', 'info': 'Number of animes : 4', 'note': ''},
#  {'from': '4.0', 'id': 'none', 'info': 'Number of animes : 17', 'note': ''},
#  {'from': '5.0', 'id': 'none', 'info': 'Number of animes : 94', 'note': ''},
#  {'from': '6.0', 'id': 'none', 'info': 'Number of animes : 875', 'note': ''},
#  {'from': '7.0', 'id': 'none', 'info': 'Number of animes : 2702', 'note': ''},
#  {'from': '8.0', 'id': 'none', 'info': 'Number of animes : 1900', 'note': ''},
#  {'from': '9.0', 'id': 'none', 'info': 'Number of animes : 118', 'note': ''},
#  {'from': 'A-1 Pictures', 'id': 'APsAc-0', 'to': 'Action', 'value': 66},
#  {'from': 'Production I.G', 'id': 'PrGAc-0', 'to': 'Action', 'value': 81},
#  {'from': 'A-1 Pictures', 'id': 'APsAd-0', 'to': 'Adventure', 'value': 28},
#  {'from': 'Production I.G', 'id': 'PrGAd-0', 'to': 'Adventure', 'value': 35},
#  {'from': 'Studio Deen', 'id': 'StnAd-0', 'to': 'Adventure', 'value': 34},
#  {'from': 'A-1 Pictures', 'id': 'APsCo-0', 'to': 'Comedy', 'value': 85},
#  {'from': 'Production I.G', 'id': 'PrGCo-0', 'to': 'Comedy', 'value': 87},
#  {'from': 'Studio Deen', 'id': 'StnCo-0', 'to': 'Comedy', 'value': 129},
#  {'from': 'A-1 Pictures', 'id': 'APsDr-0', 'to': 'Drama', 'value': 25},
#  {'from': 'Production I.G', 'id': 'PrGDr-0', 'to': 'Drama', 'value': 61},
#  {'from': 'Studio Deen', 'id': 'StnDr-0', 'to': 'Drama', 'value': 64},
#  {'from': 'A-1 Pictures', 'id': 'APsFa-0', 'to': 'Fantasy', 'value': 59},
#  {'from': 'Production I.G', 'id': 'PrGFa-0', 'to': 'Fantasy', 'value': 45},
#  {'from': 'Studio Deen', 'id': 'StnFa-0', 'to': 'Fantasy', 'value': 51},
#  {'from': 'A-1 Pictures', 'id': 'APsRo-0', 'to': 'Romance', 'value': 33},
#  {'from': 'Production I.G', 'id': 'PrGRo-0', 'to': 'Romance', 'value': 31},
#  {'from': 'Studio Deen', 'id': 'StnRo-0', 'to': 'Romance', 'value': 57},
#  {'from': 'A-1 Pictures', 'id': 'APsSc-0', 'to': 'Sci-Fi', 'value': 28},
#  {'from': 'Production I.G', 'id': 'PrGSc-0', 'to': 'Sci-Fi', 'value': 57},
#  {'from': 'Studio Deen', 'id': 'StnSc-0', 'to': 'Sci-Fi', 'value': 29},
#  {'from': 'A-1 Pictures', 'id': 'APsSh-0', 'to': 'Shounen', 'value': 39},
#  {'from': 'AIC', 'id': 'AICAc-0', 'to': 'Action', 'value': 55},
#  {'from': 'J.C.Staff', 'id': 'JCfAc-0', 'to': 'Action', 'value': 60},
#  {'from': 'Madhouse', 'id': 'MaeAc-0', 'to': 'Action', 'value': 93},
#  {'from': 'Sunrise', 'id': 'SueAc-0', 'to': 'Action', 'value': 161},
#  {'from': 'Toei Animation', 'id': 'TonAc-0', 'to': 'Action', 'value': 187},
#  {'from': 'J.C.Staff', 'id': 'JCfAd-0', 'to': 'Adventure', 'value': 38},
#  {'from': 'Madhouse', 'id': 'MaeAd-0', 'to': 'Adventure', 'value': 78},
#  {'from': 'Sunrise', 'id': 'SueAd-0', 'to': 'Adventure', 'value': 71},
#  {'from': 'Toei Animation', 'id': 'TonAd-0', 'to': 'Adventure', 'value': 170},
#  {'from': 'J.C.Staff', 'id': 'JCfCo-0', 'to': 'Comedy', 'value': 139},
#  {'from': 'Madhouse', 'id': 'MaeCo-0', 'to': 'Comedy', 'value': 107},
#  {'from': 'Sunrise', 'id': 'SueCo-0', 'to': 'Comedy', 'value': 84},
#  {'from': 'Toei Animation', 'id': 'TonCo-0', 'to': 'Comedy', 'value': 211},
#  {'from': 'J.C.Staff', 'id': 'JCfDr-0', 'to': 'Drama', 'value': 66},
#  {'from': 'Madhouse', 'id': 'MaeDr-0', 'to': 'Drama', 'value': 110},
#  {'from': 'Sunrise', 'id': 'SueDr-0', 'to': 'Drama', 'value': 84},
#  {'from': 'Toei Animation', 'id': 'TonDr-0', 'to': 'Drama', 'value': 95},
#  {'from': 'J.C.Staff', 'id': 'JCfFa-0', 'to': 'Fantasy', 'value': 53},
#  {'from': 'Madhouse', 'id': 'MaeFa-0', 'to': 'Fantasy', 'value': 63},
#  {'from': 'Sunrise', 'id': 'SueFa-0', 'to': 'Fantasy', 'value': 32},
#  {'from': 'Toei Animation', 'id': 'TonFa-0', 'to': 'Fantasy', 'value': 192},
#  {'from': 'J.C.Staff', 'id': 'JCfRo-0', 'to': 'Romance', 'value': 79},
#  {'from': 'Madhouse', 'id': 'MaeRo-0', 'to': 'Romance', 'value': 58},
#  {'from': 'Sunrise', 'id': 'SueRo-0', 'to': 'Romance', 'value': 40},
#  {'from': 'Toei Animation', 'id': 'TonRo-0', 'to': 'Romance', 'value': 43},
#  {'from': 'J.C.Staff', 'id': 'JCfSc-0', 'to': 'Sci-Fi', 'value': 37},
#  {'from': 'Madhouse', 'id': 'MaeSc-0', 'to': 'Sci-Fi', 'value': 71},
#  {'from': 'Sunrise', 'id': 'SueSc-0', 'to': 'Sci-Fi', 'value': 173},
#  {'from': 'Toei Animation', 'id': 'TonSc-0', 'to': 'Sci-Fi', 'value': 113},
#  {'from': 'J.C.Staff', 'id': 'JCfSh-0', 'to': 'Shounen', 'value': 62},
#  {'from': 'Madhouse', 'id': 'MaeSh-0', 'to': 'Shounen', 'value': 55},
#  {'from': 'Studio Deen', 'id': 'StnAc-0', 'to': 'Action', 'value': 66},
#  {'from': 'Studio Pierrot', 'id': 'SttAc-0', 'to': 'Action', 'value': 91},
#  {'from': 'TMS Entertainment', 'id': 'TMtAc-0', 'to': 'Action', 'value': 52},
#  {'from': 'AIC', 'id': 'AICAd-0', 'to': 'Adventure', 'value': 33},
#  {'from': 'Studio Pierrot', 'id': 'SttAd-0', 'to': 'Adventure', 'value': 75},
#  {'from': 'TMS Entertainment', 'id': 'TMtAd-0', 'to': 'Adventure', 'value': 70},
#  {'from': 'AIC', 'id': 'AICCo-0', 'to': 'Comedy', 'value': 92},
#  {'from': 'Studio Pierrot', 'id': 'SttCo-0', 'to': 'Comedy', 'value': 137},
#  {'from': 'TMS Entertainment', 'id': 'TMtCo-0', 'to': 'Comedy', 'value': 102},
#  {'from': 'AIC', 'id': 'AICDr-0', 'to': 'Drama', 'value': 28},
#  {'from': 'Studio Pierrot', 'id': 'SttDr-0', 'to': 'Drama', 'value': 52},
#  {'from': 'TMS Entertainment', 'id': 'TMtDr-0', 'to': 'Drama', 'value': 29},
#  {'from': 'AIC', 'id': 'AICFa-0', 'to': 'Fantasy', 'value': 26},
#  {'from': 'Studio Pierrot', 'id': 'SttFa-0', 'to': 'Fantasy', 'value': 42},
#  {'from': 'TMS Entertainment', 'id': 'TMtFa-0', 'to': 'Fantasy', 'value': 29},
#  {'from': 'AIC', 'id': 'AICRo-0', 'to': 'Romance', 'value': 56},
#  {'from': 'Studio Pierrot', 'id': 'SttRo-0', 'to': 'Romance', 'value': 47},
#  {'from': 'TMS Entertainment', 'id': 'TMtRo-0', 'to': 'Romance', 'value': 21},
#  {'from': 'AIC', 'id': 'AICSc-0', 'to': 'Sci-Fi', 'value': 65},
#  {'from': 'Studio Pierrot', 'id': 'SttSc-0', 'to': 'Sci-Fi', 'value': 42},
#  {'from': 'TMS Entertainment', 'id': 'TMtSc-0', 'to': 'Sci-Fi', 'value': 16},
#  {'from': 'AIC', 'id': 'AICSh-0', 'to': 'Shounen', 'value': 32},
#  {'from': 'Production I.G', 'id': 'PrGSh-0', 'to': 'Shounen', 'value': 53},
#  {'from': 'Studio Deen', 'id': 'StnSh-0', 'to': 'Shounen', 'value': 52},
#  {'from': 'Studio Pierrot', 'id': 'SttSh-0', 'to': 'Shounen', 'value': 88},
#  {'from': 'Sunrise', 'id': 'SueSh-0', 'to': 'Shounen', 'value': 53},
#  {'from': 'TMS Entertainment', 'id': 'TMtSh-0', 'to': 'Shounen', 'value': 68},
#  {'from': 'Toei Animation', 'id': 'TonSh-0', 'to': 'Shounen', 'value': 191},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '6.0', 'value': 27},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '7.0', 'value': 112},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '8.0', 'value': 45},
#  {'from': 'Action', 'id': 'TonAc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '6.0', 'value': 5},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '7.0', 'value': 22},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '8.0', 'value': 16},
#  {'from': 'Romance', 'id': 'TonRo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '5.0', 'value': 1},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '6.0', 'value': 7},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '7.0', 'value': 49},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '8.0', 'value': 36},
#  {'from': 'Drama', 'id': 'TonDr-1', 'to': '9.0', 'value': 2},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '6.0', 'value': 31},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '7.0', 'value': 62},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '8.0', 'value': 18},
#  {'from': 'Sci-Fi', 'id': 'TonSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '5.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '6.0', 'value': 32},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '7.0', 'value': 106},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '8.0', 'value': 50},
#  {'from': 'Shounen', 'id': 'TonSh-1', 'to': '9.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '2.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '4.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '6.0', 'value': 42},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '7.0', 'value': 112},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '8.0', 'value': 51},
#  {'from': 'Comedy', 'id': 'TonCo-1', 'to': '9.0', 'value': 2},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '2.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '5.0', 'value': 3},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '6.0', 'value': 16},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '7.0', 'value': 123},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '8.0', 'value': 48},
#  {'from': 'Fantasy', 'id': 'TonFa-1', 'to': '9.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '5.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '6.0', 'value': 21},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '7.0', 'value': 95},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '8.0', 'value': 52},
#  {'from': 'Adventure', 'id': 'TonAd-1', 'to': '9.0', 'value': 1},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '6.0', 'value': 16},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '7.0', 'value': 79},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '8.0', 'value': 56},
#  {'from': 'Action', 'id': 'SueAc-1', 'to': '9.0', 'value': 9},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '6.0', 'value': 2},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '7.0', 'value': 18},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '8.0', 'value': 20},
#  {'from': 'Romance', 'id': 'SueRo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '5.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '6.0', 'value': 9},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '7.0', 'value': 39},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '8.0', 'value': 33},
#  {'from': 'Drama', 'id': 'SueDr-1', 'to': '9.0', 'value': 3},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '6.0', 'value': 17},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '7.0', 'value': 92},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '8.0', 'value': 53},
#  {'from': 'Sci-Fi', 'id': 'SueSc-1', 'to': '9.0', 'value': 9},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '5.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '6.0', 'value': 4},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '7.0', 'value': 17},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '8.0', 'value': 26},
#  {'from': 'Shounen', 'id': 'SueSh-1', 'to': '9.0', 'value': 6},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '6.0', 'value': 6},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '7.0', 'value': 36},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '8.0', 'value': 33},
#  {'from': 'Comedy', 'id': 'SueCo-1', 'to': '9.0', 'value': 7},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '5.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '6.0', 'value': 7},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '7.0', 'value': 15},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '8.0', 'value': 9},
#  {'from': 'Fantasy', 'id': 'SueFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '5.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '6.0', 'value': 7},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '7.0', 'value': 41},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '8.0', 'value': 21},
#  {'from': 'Adventure', 'id': 'SueAd-1', 'to': '9.0', 'value': 1},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '5.0', 'value': 3},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '6.0', 'value': 20},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '7.0', 'value': 37},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '8.0', 'value': 29},
#  {'from': 'Action', 'id': 'MaeAc-1', 'to': '9.0', 'value': 4},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '5.0', 'value': 4},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '6.0', 'value': 11},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '7.0', 'value': 19},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '8.0', 'value': 22},
#  {'from': 'Romance', 'id': 'MaeRo-1', 'to': '9.0', 'value': 2},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '5.0', 'value': 1},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '6.0', 'value': 17},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '7.0', 'value': 45},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '8.0', 'value': 40},
#  {'from': 'Drama', 'id': 'MaeDr-1', 'to': '9.0', 'value': 7},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '6.0', 'value': 10},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '7.0', 'value': 35},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '8.0', 'value': 23},
#  {'from': 'Sci-Fi', 'id': 'MaeSc-1', 'to': '9.0', 'value': 2},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '5.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '6.0', 'value': 4},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '7.0', 'value': 30},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '8.0', 'value': 15},
#  {'from': 'Shounen', 'id': 'MaeSh-1', 'to': '9.0', 'value': 5},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '6.0', 'value': 18},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '7.0', 'value': 46},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '8.0', 'value': 34},
#  {'from': 'Comedy', 'id': 'MaeCo-1', 'to': '9.0', 'value': 7},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '5.0', 'value': 2},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '6.0', 'value': 9},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '7.0', 'value': 28},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '8.0', 'value': 23},
#  {'from': 'Fantasy', 'id': 'MaeFa-1', 'to': '9.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '5.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '6.0', 'value': 14},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '7.0', 'value': 34},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '8.0', 'value': 27},
#  {'from': 'Adventure', 'id': 'MaeAd-1', 'to': '9.0', 'value': 2},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '4.0', 'value': 2},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '5.0', 'value': 3},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '6.0', 'value': 22},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '7.0', 'value': 17},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '8.0', 'value': 16},
#  {'from': 'Action', 'id': 'JCfAc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '4.0', 'value': 1},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '6.0', 'value': 7},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '7.0', 'value': 33},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '8.0', 'value': 35},
#  {'from': 'Romance', 'id': 'JCfRo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '5.0', 'value': 1},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '6.0', 'value': 10},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '7.0', 'value': 30},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '8.0', 'value': 24},
#  {'from': 'Drama', 'id': 'JCfDr-1', 'to': '9.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '6.0', 'value': 14},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '7.0', 'value': 11},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '8.0', 'value': 11},
#  {'from': 'Sci-Fi', 'id': 'JCfSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '5.0', 'value': 2},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '6.0', 'value': 11},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '7.0', 'value': 29},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '8.0', 'value': 15},
#  {'from': 'Shounen', 'id': 'JCfSh-1', 'to': '9.0', 'value': 5},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '6.0', 'value': 18},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '7.0', 'value': 74},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '8.0', 'value': 42},
#  {'from': 'Comedy', 'id': 'JCfCo-1', 'to': '9.0', 'value': 3},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '4.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '5.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '6.0', 'value': 11},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '7.0', 'value': 28},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '8.0', 'value': 13},
#  {'from': 'Fantasy', 'id': 'JCfFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '5.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '6.0', 'value': 14},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '7.0', 'value': 16},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '8.0', 'value': 8},
#  {'from': 'Adventure', 'id': 'JCfAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '6.0', 'value': 19},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '7.0', 'value': 40},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '8.0', 'value': 29},
#  {'from': 'Action', 'id': 'SttAc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '6.0', 'value': 9},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '7.0', 'value': 21},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '8.0', 'value': 15},
#  {'from': 'Romance', 'id': 'SttRo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '5.0', 'value': 0},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '6.0', 'value': 8},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '7.0', 'value': 24},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '8.0', 'value': 19},
#  {'from': 'Drama', 'id': 'SttDr-1', 'to': '9.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '6.0', 'value': 21},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '7.0', 'value': 15},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '8.0', 'value': 5},
#  {'from': 'Sci-Fi', 'id': 'SttSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '5.0', 'value': 3},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '6.0', 'value': 11},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '7.0', 'value': 43},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '8.0', 'value': 30},
#  {'from': 'Shounen', 'id': 'SttSh-1', 'to': '9.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '5.0', 'value': 3},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '6.0', 'value': 35},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '7.0', 'value': 64},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '8.0', 'value': 34},
#  {'from': 'Comedy', 'id': 'SttCo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '5.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '6.0', 'value': 9},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '7.0', 'value': 19},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '8.0', 'value': 13},
#  {'from': 'Fantasy', 'id': 'SttFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '5.0', 'value': 2},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '6.0', 'value': 11},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '7.0', 'value': 40},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '8.0', 'value': 22},
#  {'from': 'Adventure', 'id': 'SttAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '6.0', 'value': 6},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '7.0', 'value': 29},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '8.0', 'value': 28},
#  {'from': 'Action', 'id': 'StnAc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '6.0', 'value': 4},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '7.0', 'value': 27},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '8.0', 'value': 25},
#  {'from': 'Romance', 'id': 'StnRo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '5.0', 'value': 0},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '6.0', 'value': 3},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '7.0', 'value': 20},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '8.0', 'value': 38},
#  {'from': 'Drama', 'id': 'StnDr-1', 'to': '9.0', 'value': 3},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '4.0', 'value': 3},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '5.0', 'value': 3},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '6.0', 'value': 4},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '7.0', 'value': 14},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '8.0', 'value': 5},
#  {'from': 'Sci-Fi', 'id': 'StnSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '5.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '6.0', 'value': 6},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '7.0', 'value': 25},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '8.0', 'value': 21},
#  {'from': 'Shounen', 'id': 'StnSh-1', 'to': '9.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '4.0', 'value': 3},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '5.0', 'value': 5},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '6.0', 'value': 16},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '7.0', 'value': 56},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '8.0', 'value': 49},
#  {'from': 'Comedy', 'id': 'StnCo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '4.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '5.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '6.0', 'value': 4},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '7.0', 'value': 25},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '8.0', 'value': 21},
#  {'from': 'Fantasy', 'id': 'StnFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '5.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '6.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '7.0', 'value': 19},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '8.0', 'value': 13},
#  {'from': 'Adventure', 'id': 'StnAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '3.0', 'value': 1},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '5.0', 'value': 2},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '6.0', 'value': 16},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '7.0', 'value': 26},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '8.0', 'value': 35},
#  {'from': 'Action', 'id': 'PrGAc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '6.0', 'value': 3},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '7.0', 'value': 11},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '8.0', 'value': 15},
#  {'from': 'Romance', 'id': 'PrGRo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '5.0', 'value': 1},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '6.0', 'value': 4},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '7.0', 'value': 24},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '8.0', 'value': 29},
#  {'from': 'Drama', 'id': 'PrGDr-1', 'to': '9.0', 'value': 3},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '6.0', 'value': 5},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '7.0', 'value': 29},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '8.0', 'value': 21},
#  {'from': 'Sci-Fi', 'id': 'PrGSc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '5.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '6.0', 'value': 3},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '7.0', 'value': 13},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '8.0', 'value': 33},
#  {'from': 'Shounen', 'id': 'PrGSh-1', 'to': '9.0', 'value': 4},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '3.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '4.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '5.0', 'value': 3},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '6.0', 'value': 14},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '7.0', 'value': 24},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '8.0', 'value': 40},
#  {'from': 'Comedy', 'id': 'PrGCo-1', 'to': '9.0', 'value': 4},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '3.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '4.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '5.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '6.0', 'value': 13},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '7.0', 'value': 18},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '8.0', 'value': 12},
#  {'from': 'Fantasy', 'id': 'PrGFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '3.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '5.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '6.0', 'value': 8},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '7.0', 'value': 20},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '8.0', 'value': 6},
#  {'from': 'Adventure', 'id': 'PrGAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '5.0', 'value': 0},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '6.0', 'value': 9},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '7.0', 'value': 30},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '8.0', 'value': 26},
#  {'from': 'Action', 'id': 'APsAc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '6.0', 'value': 2},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '7.0', 'value': 17},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '8.0', 'value': 13},
#  {'from': 'Romance', 'id': 'APsRo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '5.0', 'value': 0},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '6.0', 'value': 6},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '7.0', 'value': 9},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '8.0', 'value': 8},
#  {'from': 'Drama', 'id': 'APsDr-1', 'to': '9.0', 'value': 2},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '5.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '6.0', 'value': 4},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '7.0', 'value': 13},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '8.0', 'value': 10},
#  {'from': 'Sci-Fi', 'id': 'APsSc-1', 'to': '9.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '5.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '6.0', 'value': 2},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '7.0', 'value': 13},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '8.0', 'value': 23},
#  {'from': 'Shounen', 'id': 'APsSh-1', 'to': '9.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '5.0', 'value': 2},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '6.0', 'value': 6},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '7.0', 'value': 38},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '8.0', 'value': 37},
#  {'from': 'Comedy', 'id': 'APsCo-1', 'to': '9.0', 'value': 2},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '5.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '6.0', 'value': 4},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '7.0', 'value': 25},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '8.0', 'value': 28},
#  {'from': 'Fantasy', 'id': 'APsFa-1', 'to': '9.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '5.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '6.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '7.0', 'value': 12},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '8.0', 'value': 15},
#  {'from': 'Adventure', 'id': 'APsAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '6.0', 'value': 5},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '7.0', 'value': 32},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '8.0', 'value': 14},
#  {'from': 'Action', 'id': 'TMtAc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '6.0', 'value': 1},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '7.0', 'value': 6},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '8.0', 'value': 13},
#  {'from': 'Romance', 'id': 'TMtRo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '5.0', 'value': 0},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '6.0', 'value': 2},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '7.0', 'value': 12},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '8.0', 'value': 15},
#  {'from': 'Drama', 'id': 'TMtDr-1', 'to': '9.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '5.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '6.0', 'value': 7},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '7.0', 'value': 7},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '8.0', 'value': 1},
#  {'from': 'Sci-Fi', 'id': 'TMtSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '4.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '5.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '6.0', 'value': 4},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '7.0', 'value': 24},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '8.0', 'value': 40},
#  {'from': 'Shounen', 'id': 'TMtSh-1', 'to': '9.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '4.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '5.0', 'value': 5},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '6.0', 'value': 17},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '7.0', 'value': 37},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '8.0', 'value': 41},
#  {'from': 'Comedy', 'id': 'TMtCo-1', 'to': '9.0', 'value': 1},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '5.0', 'value': 2},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '6.0', 'value': 7},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '7.0', 'value': 14},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '8.0', 'value': 5},
#  {'from': 'Fantasy', 'id': 'TMtFa-1', 'to': '9.0', 'value': 1},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '5.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '6.0', 'value': 6},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '7.0', 'value': 31},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '8.0', 'value': 33},
#  {'from': 'Adventure', 'id': 'TMtAd-1', 'to': '9.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '5.0', 'value': 0},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '6.0', 'value': 19},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '7.0', 'value': 29},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '8.0', 'value': 7},
#  {'from': 'Action', 'id': 'AICAc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '4.0', 'value': 0},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '5.0', 'value': 1},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '6.0', 'value': 3},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '7.0', 'value': 37},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '8.0', 'value': 15},
#  {'from': 'Romance', 'id': 'AICRo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '0.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '1.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '2.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '3.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '4.0', 'value': 0},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '5.0', 'value': 1},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '6.0', 'value': 5},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '7.0', 'value': 16},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '8.0', 'value': 6},
#  {'from': 'Drama', 'id': 'AICDr-1', 'to': '9.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '0.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '1.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '2.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '3.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '4.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '5.0', 'value': 0},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '6.0', 'value': 20},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '7.0', 'value': 32},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '8.0', 'value': 13},
#  {'from': 'Sci-Fi', 'id': 'AICSc-1', 'to': '9.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '0.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '1.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '2.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '3.0', 'value': 0},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '4.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '5.0', 'value': 1},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '6.0', 'value': 7},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '7.0', 'value': 16},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '8.0', 'value': 7},
#  {'from': 'Shounen', 'id': 'AICSh-1', 'to': '9.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '0.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '1.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '2.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '3.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '4.0', 'value': 1},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '5.0', 'value': 0},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '6.0', 'value': 21},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '7.0', 'value': 49},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '8.0', 'value': 21},
#  {'from': 'Comedy', 'id': 'AICCo-1', 'to': '9.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '0.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '1.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '2.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '3.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '4.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '5.0', 'value': 0},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '6.0', 'value': 11},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '7.0', 'value': 11},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '8.0', 'value': 4},
#  {'from': 'Fantasy', 'id': 'AICFa-1', 'to': '9.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '0.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '1.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '2.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '3.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '4.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '5.0', 'value': 0},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '6.0', 'value': 14},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '7.0', 'value': 16},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '8.0', 'value': 3},
#  {'from': 'Adventure', 'id': 'AICAd-1', 'to': '9.0', 'value': 0}]
